# %% [markdown]
# RESIZE

# %%
import numpy as np
import cv2 as cv
import os

folder_path = 'C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\InteligenciaArtificial\\Imagenes\\wally\\n'  # Reemplaza con la ruta correcta
def resize_images(folder_path, size=(40, 40)):
    # Verificar si la carpeta existe
    if not os.path.exists(folder_path):
        print(f"La carpeta {folder_path} no existe.")
        return

    for filename in os.listdir(folder_path):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            try:
                img_path = os.path.join(folder_path, filename)
                img = cv.imread(img_path)
                if img is not None:
                    # Redimensionar la imagen
                    img_resized = cv.resize(img, size, interpolation=cv.INTER_AREA)
                    # Sobrescribir la imagen original con la imagen redimensionada
                    cv.imwrite(img_path, img_resized)
                    print(f"Imagen {filename} redimensionada a {size}.")
                else:
                    print(f"No se pudo leer la imagen {filename}.")
            except Exception as e:
                print(f"No se pudo redimensionar la imagen {filename}: {e}")


#Llamar a la función para redimensionar imágenes
resize_images(folder_path)
# Out:
# Imagen 1_0_0.jpg redimensionada a (40, 40).
# Imagen 1_0_1.jpg redimensionada a (40, 40).
# Imagen 1_0_10.jpg redimensionada a (40, 40).
# Imagen 1_0_11.jpg redimensionada a (40, 40).
# Imagen 1_0_12.jpg redimensionada a (40, 40).
# Imagen 1_0_13.jpg redimensionada a (40, 40).
# Imagen 1_0_14.jpg redimensionada a (40, 40).
# Imagen 1_0_15.jpg redimensionada a (40, 40).
# Imagen 1_0_2.jpg redimensionada a (40, 40).
# Imagen 1_0_3.jpg redimensionada a (40, 40).
# Imagen 1_0_4.jpg redimensionada a (40, 40).
# Imagen 1_0_5.jpg redimensionada a (40, 40).
# Imagen 1_0_6.jpg redimensionada a (40, 40).
# Imagen 1_0_7.jpg redimensionada a (40, 40).
# Imagen 1_0_8.jpg redimensionada a (40, 40).
# Imagen 1_0_9.jpg redimensionada a (40, 40).
# Imagen 1_10_0.jpg redimensionada a (40, 40).
# Imagen 1_10_1.jpg redimensionada a (40, 40).
# Imagen 1_10_10.jpg redimensionada a (40, 40).
# Imagen 1_10_11.jpg redimensionada a (40, 40).
# Imagen 1_10_12.jpg redimensionada a (40, 40).
# Imagen 1_10_13.jpg redimensionada a (40, 40).
# Imagen 1_10_14.jpg redimensionada a (40, 40).
# Imagen 1_10_15.jpg redimensionada a (40, 40).
# Imagen 1_10_2.jpg redimensionada a (40, 40).
# Imagen 1_10_3.jpg redimensionada a (40, 40).
# Imagen 1_10_4.jpg redimensionada a (40, 40).
# Imagen 1_10_5.jpg redimensionada a (40, 40).
# Imagen 1_10_6.jpg redimensionada a (40, 40).
# Imagen 1_10_7.jpg redimensionada a (40, 40).
# Imagen 1_10_8.jpg redimensionada a (40, 40).
# Imagen 1_10_9.jpg redimensionada a (40, 40).
# Imagen 1_11_0.jpg redimensionada a (40, 40).
# Imagen 1_11_1.jpg redimensionada a (40, 40).
# Imagen 1_11_10.jpg redimensionada a (40, 40).
# Imagen 1_11_11.jpg redimensionada a (40, 40).
# Imagen 1_11_12.jpg redimensionada a (40, 40).
# Imagen 1_11_13.jpg redimensionada a (40, 40).
# Imagen 1_11_14.jpg redimensionada a (40, 40).
# Imagen 1_11_15.jpg redimensionada a (40, 40).
# Imagen 1_11_2.jpg redimensionada a (40, 40).
# Imagen 1_11_3.jpg redimensionada a (40, 40).
# Imagen 1_11_4.jpg redimensionada a (40, 40).
# Imagen 1_11_5.jpg redimensionada a (40, 40).
# Imagen 1_11_6.jpg redimensionada a (40, 40).
# Imagen 1_11_7.jpg redimensionada a (40, 40).
# Imagen 1_11_8.jpg redimensionada a (40, 40).
# Imagen 1_11_9.jpg redimensionada a (40, 40).
# Imagen 1_12_0.jpg redimensionada a (40, 40).
# Imagen 1_12_1.jpg redimensionada a (40, 40).
# Imagen 1_12_10.jpg redimensionada a (40, 40).
# Imagen 1_12_11.jpg redimensionada a (40, 40).
# Imagen 1_12_12.jpg redimensionada a (40, 40).
# Imagen 1_12_13.jpg redimensionada a (40, 40).
# Imagen 1_12_14.jpg redimensionada a (40, 40).
# Imagen 1_12_15.jpg redimensionada a (40, 40).
# Imagen 1_12_2.jpg redimensionada a (40, 40).
# Imagen 1_12_3.jpg redimensionada a (40, 40).
# Imagen 1_12_4.jpg redimensionada a (40, 40).
# Imagen 1_12_5.jpg redimensionada a (40, 40).
# Imagen 1_12_6.jpg redimensionada a (40, 40).
# Imagen 1_12_7.jpg redimensionada a (40, 40).
# Imagen 1_12_8.jpg redimensionada a (40, 40).
# Imagen 1_12_9.jpg redimensionada a (40, 40).
# Imagen 1_13_0.jpg redimensionada a (40, 40).
# Imagen 1_13_1.jpg redimensionada a (40, 40).
# Imagen 1_13_10.jpg redimensionada a (40, 40).
# Imagen 1_13_11.jpg redimensionada a (40, 40).
# Imagen 1_13_12.jpg redimensionada a (40, 40).
# Imagen 1_13_13.jpg redimensionada a (40, 40).
# Imagen 1_13_14.jpg redimensionada a (40, 40).
# Imagen 1_13_15.jpg redimensionada a (40, 40).
# Imagen 1_13_2.jpg redimensionada a (40, 40).
# Imagen 1_13_3.jpg redimensionada a (40, 40).
# Imagen 1_13_4.jpg redimensionada a (40, 40).
# Imagen 1_13_5.jpg redimensionada a (40, 40).
# Imagen 1_13_6.jpg redimensionada a (40, 40).
# Imagen 1_13_7.jpg redimensionada a (40, 40).
# Imagen 1_13_8.jpg redimensionada a (40, 40).
# Imagen 1_13_9.jpg redimensionada a (40, 40).
# Imagen 1_14_0.jpg redimensionada a (40, 40).
# Imagen 1_14_1.jpg redimensionada a (40, 40).
# Imagen 1_14_10.jpg redimensionada a (40, 40).
# Imagen 1_14_11.jpg redimensionada a (40, 40).
# Imagen 1_14_12.jpg redimensionada a (40, 40).
# Imagen 1_14_13.jpg redimensionada a (40, 40).
# Imagen 1_14_14.jpg redimensionada a (40, 40).
# Imagen 1_14_15.jpg redimensionada a (40, 40).
# Imagen 1_14_2.jpg redimensionada a (40, 40).
# Imagen 1_14_3.jpg redimensionada a (40, 40).
# Imagen 1_14_4.jpg redimensionada a (40, 40).
# Imagen 1_14_5.jpg redimensionada a (40, 40).
# Imagen 1_14_6.jpg redimensionada a (40, 40).
# Imagen 1_14_7.jpg redimensionada a (40, 40).
# Imagen 1_14_8.jpg redimensionada a (40, 40).
# Imagen 1_14_9.jpg redimensionada a (40, 40).
# Imagen 1_15_0.jpg redimensionada a (40, 40).
# Imagen 1_15_1.jpg redimensionada a (40, 40).
# Imagen 1_15_10.jpg redimensionada a (40, 40).
# Imagen 1_15_11.jpg redimensionada a (40, 40).
# Imagen 1_15_12.jpg redimensionada a (40, 40).
# Imagen 1_15_13.jpg redimensionada a (40, 40).
# Imagen 1_15_14.jpg redimensionada a (40, 40).
# Imagen 1_15_15.jpg redimensionada a (40, 40).
# Imagen 1_15_2.jpg redimensionada a (40, 40).
# Imagen 1_15_3.jpg redimensionada a (40, 40).
# Imagen 1_15_4.jpg redimensionada a (40, 40).
# Imagen 1_15_5.jpg redimensionada a (40, 40).
# Imagen 1_15_6.jpg redimensionada a (40, 40).
# Imagen 1_15_7.jpg redimensionada a (40, 40).
# Imagen 1_15_8.jpg redimensionada a (40, 40).
# Imagen 1_15_9.jpg redimensionada a (40, 40).
# Imagen 1_1_0.jpg redimensionada a (40, 40).
# Imagen 1_1_1.jpg redimensionada a (40, 40).
# Imagen 1_1_10.jpg redimensionada a (40, 40).
# Imagen 1_1_11.jpg redimensionada a (40, 40).
# Imagen 1_1_12.jpg redimensionada a (40, 40).
# Imagen 1_1_13.jpg redimensionada a (40, 40).
# Imagen 1_1_14.jpg redimensionada a (40, 40).
# Imagen 1_1_15.jpg redimensionada a (40, 40).
# Imagen 1_1_2.jpg redimensionada a (40, 40).
# Imagen 1_1_3.jpg redimensionada a (40, 40).
# Imagen 1_1_4.jpg redimensionada a (40, 40).
# Imagen 1_1_5.jpg redimensionada a (40, 40).
# Imagen 1_1_6.jpg redimensionada a (40, 40).
# Imagen 1_1_7.jpg redimensionada a (40, 40).
# Imagen 1_1_8.jpg redimensionada a (40, 40).
# Imagen 1_1_9.jpg redimensionada a (40, 40).
# Imagen 1_2_0.jpg redimensionada a (40, 40).
# Imagen 1_2_1.jpg redimensionada a (40, 40).
# Imagen 1_2_10.jpg redimensionada a (40, 40).
# Imagen 1_2_11.jpg redimensionada a (40, 40).
# Imagen 1_2_12.jpg redimensionada a (40, 40).
# Imagen 1_2_13.jpg redimensionada a (40, 40).
# Imagen 1_2_14.jpg redimensionada a (40, 40).
# Imagen 1_2_15.jpg redimensionada a (40, 40).
# Imagen 1_2_2.jpg redimensionada a (40, 40).
# Imagen 1_2_3.jpg redimensionada a (40, 40).
# Imagen 1_2_4.jpg redimensionada a (40, 40).
# Imagen 1_2_5.jpg redimensionada a (40, 40).
# Imagen 1_2_6.jpg redimensionada a (40, 40).
# Imagen 1_2_7.jpg redimensionada a (40, 40).
# Imagen 1_2_8.jpg redimensionada a (40, 40).
# Imagen 1_2_9.jpg redimensionada a (40, 40).
# Imagen 1_3_0.jpg redimensionada a (40, 40).
# Imagen 1_3_1.jpg redimensionada a (40, 40).
# Imagen 1_3_10.jpg redimensionada a (40, 40).
# Imagen 1_3_11.jpg redimensionada a (40, 40).
# Imagen 1_3_12.jpg redimensionada a (40, 40).
# Imagen 1_3_13.jpg redimensionada a (40, 40).
# Imagen 1_3_14.jpg redimensionada a (40, 40).
# Imagen 1_3_15.jpg redimensionada a (40, 40).
# Imagen 1_3_2.jpg redimensionada a (40, 40).
# Imagen 1_3_3.jpg redimensionada a (40, 40).
# Imagen 1_3_4.jpg redimensionada a (40, 40).
# Imagen 1_3_5.jpg redimensionada a (40, 40).
# Imagen 1_3_6.jpg redimensionada a (40, 40).
# Imagen 1_3_7.jpg redimensionada a (40, 40).
# Imagen 1_3_8.jpg redimensionada a (40, 40).
# Imagen 1_3_9.jpg redimensionada a (40, 40).
# Imagen 1_4_0.jpg redimensionada a (40, 40).
# Imagen 1_4_1.jpg redimensionada a (40, 40).
# Imagen 1_4_10.jpg redimensionada a (40, 40).
# Imagen 1_4_11.jpg redimensionada a (40, 40).
# Imagen 1_4_12.jpg redimensionada a (40, 40).
# Imagen 1_4_13.jpg redimensionada a (40, 40).
# Imagen 1_4_14.jpg redimensionada a (40, 40).
# Imagen 1_4_15.jpg redimensionada a (40, 40).
# Imagen 1_4_2.jpg redimensionada a (40, 40).
# Imagen 1_4_3.jpg redimensionada a (40, 40).
# Imagen 1_4_4.jpg redimensionada a (40, 40).
# Imagen 1_4_5.jpg redimensionada a (40, 40).
# Imagen 1_4_8.jpg redimensionada a (40, 40).
# Imagen 1_4_9.jpg redimensionada a (40, 40).
# Imagen 1_5_0.jpg redimensionada a (40, 40).
# Imagen 1_5_1.jpg redimensionada a (40, 40).
# Imagen 1_5_10.jpg redimensionada a (40, 40).
# Imagen 1_5_11.jpg redimensionada a (40, 40).
# Imagen 1_5_12.jpg redimensionada a (40, 40).
# Imagen 1_5_13.jpg redimensionada a (40, 40).
# Imagen 1_5_14.jpg redimensionada a (40, 40).
# Imagen 1_5_15.jpg redimensionada a (40, 40).
# Imagen 1_5_2.jpg redimensionada a (40, 40).
# Imagen 1_5_3.jpg redimensionada a (40, 40).
# Imagen 1_5_4.jpg redimensionada a (40, 40).
# Imagen 1_5_5.jpg redimensionada a (40, 40).
# Imagen 1_5_6.jpg redimensionada a (40, 40).
# Imagen 1_5_7.jpg redimensionada a (40, 40).
# Imagen 1_5_8.jpg redimensionada a (40, 40).
# Imagen 1_5_9.jpg redimensionada a (40, 40).
# Imagen 1_6_0.jpg redimensionada a (40, 40).
# Imagen 1_6_1.jpg redimensionada a (40, 40).
# Imagen 1_6_10.jpg redimensionada a (40, 40).
# Imagen 1_6_11.jpg redimensionada a (40, 40).
# Imagen 1_6_12.jpg redimensionada a (40, 40).
# Imagen 1_6_13.jpg redimensionada a (40, 40).
# Imagen 1_6_14.jpg redimensionada a (40, 40).
# Imagen 1_6_15.jpg redimensionada a (40, 40).
# Imagen 1_6_2.jpg redimensionada a (40, 40).
# Imagen 1_6_3.jpg redimensionada a (40, 40).
# Imagen 1_6_4.jpg redimensionada a (40, 40).
# Imagen 1_6_5.jpg redimensionada a (40, 40).
# Imagen 1_6_6.jpg redimensionada a (40, 40).
# Imagen 1_6_7.jpg redimensionada a (40, 40).
# Imagen 1_6_8.jpg redimensionada a (40, 40).
# Imagen 1_6_9.jpg redimensionada a (40, 40).
# Imagen 1_7_0.jpg redimensionada a (40, 40).
# Imagen 1_7_1.jpg redimensionada a (40, 40).
# Imagen 1_7_10.jpg redimensionada a (40, 40).
# Imagen 1_7_11.jpg redimensionada a (40, 40).
# Imagen 1_7_12.jpg redimensionada a (40, 40).
# Imagen 1_7_13.jpg redimensionada a (40, 40).
# Imagen 1_7_14.jpg redimensionada a (40, 40).
# Imagen 1_7_15.jpg redimensionada a (40, 40).
# Imagen 1_7_2.jpg redimensionada a (40, 40).
# Imagen 1_7_3.jpg redimensionada a (40, 40).
# Imagen 1_7_4.jpg redimensionada a (40, 40).
# Imagen 1_7_5.jpg redimensionada a (40, 40).
# Imagen 1_7_6.jpg redimensionada a (40, 40).
# Imagen 1_7_7.jpg redimensionada a (40, 40).
# Imagen 1_7_8.jpg redimensionada a (40, 40).
# Imagen 1_7_9.jpg redimensionada a (40, 40).
# Imagen 1_8_0.jpg redimensionada a (40, 40).
# Imagen 1_8_1.jpg redimensionada a (40, 40).
# Imagen 1_8_10.jpg redimensionada a (40, 40).
# Imagen 1_8_11.jpg redimensionada a (40, 40).
# Imagen 1_8_12.jpg redimensionada a (40, 40).
# Imagen 1_8_13.jpg redimensionada a (40, 40).
# Imagen 1_8_14.jpg redimensionada a (40, 40).
# Imagen 1_8_15.jpg redimensionada a (40, 40).
# Imagen 1_8_2.jpg redimensionada a (40, 40).
# Imagen 1_8_3.jpg redimensionada a (40, 40).
# Imagen 1_8_4.jpg redimensionada a (40, 40).
# Imagen 1_8_5.jpg redimensionada a (40, 40).
# Imagen 1_8_6.jpg redimensionada a (40, 40).
# Imagen 1_8_7.jpg redimensionada a (40, 40).
# Imagen 1_8_8.jpg redimensionada a (40, 40).
# Imagen 1_8_9.jpg redimensionada a (40, 40).
# Imagen 1_9_0.jpg redimensionada a (40, 40).
# Imagen 1_9_1.jpg redimensionada a (40, 40).
# Imagen 1_9_10.jpg redimensionada a (40, 40).
# Imagen 1_9_11.jpg redimensionada a (40, 40).
# Imagen 1_9_12.jpg redimensionada a (40, 40).
# Imagen 1_9_13.jpg redimensionada a (40, 40).
# Imagen 1_9_14.jpg redimensionada a (40, 40).
# Imagen 1_9_15.jpg redimensionada a (40, 40).
# Imagen 1_9_2.jpg redimensionada a (40, 40).
# Imagen 1_9_3.jpg redimensionada a (40, 40).
# Imagen 1_9_4.jpg redimensionada a (40, 40).
# Imagen 1_9_5.jpg redimensionada a (40, 40).
# Imagen 1_9_6.jpg redimensionada a (40, 40).
# Imagen 1_9_7.jpg redimensionada a (40, 40).
# Imagen 1_9_8.jpg redimensionada a (40, 40).
# Imagen 1_9_9.jpg redimensionada a (40, 40).
# Imagen 2_0_0.jpg redimensionada a (40, 40).
# Imagen 2_0_1.jpg redimensionada a (40, 40).
# Imagen 2_0_10.jpg redimensionada a (40, 40).
# Imagen 2_0_11.jpg redimensionada a (40, 40).
# Imagen 2_0_12.jpg redimensionada a (40, 40).
# Imagen 2_0_13.jpg redimensionada a (40, 40).
# Imagen 2_0_14.jpg redimensionada a (40, 40).
# Imagen 2_0_15.jpg redimensionada a (40, 40).
# Imagen 2_0_2.jpg redimensionada a (40, 40).
# Imagen 2_0_3.jpg redimensionada a (40, 40).
# Imagen 2_0_4.jpg redimensionada a (40, 40).
# Imagen 2_0_5.jpg redimensionada a (40, 40).
# Imagen 2_0_6.jpg redimensionada a (40, 40).
# Imagen 2_0_7.jpg redimensionada a (40, 40).
# Imagen 2_0_9.jpg redimensionada a (40, 40).
# Imagen 2_10_0.jpg redimensionada a (40, 40).
# Imagen 2_10_1.jpg redimensionada a (40, 40).
# Imagen 2_10_11.jpg redimensionada a (40, 40).
# Imagen 2_10_12.jpg redimensionada a (40, 40).
# Imagen 2_10_13.jpg redimensionada a (40, 40).
# Imagen 2_10_14.jpg redimensionada a (40, 40).
# Imagen 2_10_15.jpg redimensionada a (40, 40).
# Imagen 2_10_2.jpg redimensionada a (40, 40).
# Imagen 2_10_4.jpg redimensionada a (40, 40).
# Imagen 2_10_5.jpg redimensionada a (40, 40).
# Imagen 2_10_7.jpg redimensionada a (40, 40).
# Imagen 2_10_8.jpg redimensionada a (40, 40).
# Imagen 2_10_9.jpg redimensionada a (40, 40).
# Imagen 2_11_0.jpg redimensionada a (40, 40).
# Imagen 2_11_1.jpg redimensionada a (40, 40).
# Imagen 2_11_10.jpg redimensionada a (40, 40).
# Imagen 2_11_11.jpg redimensionada a (40, 40).
# Imagen 2_11_12.jpg redimensionada a (40, 40).
# Imagen 2_11_13.jpg redimensionada a (40, 40).
# Imagen 2_11_14.jpg redimensionada a (40, 40).
# Imagen 2_11_15.jpg redimensionada a (40, 40).
# Imagen 2_11_2.jpg redimensionada a (40, 40).
# Imagen 2_11_5.jpg redimensionada a (40, 40).
# Imagen 2_11_6.jpg redimensionada a (40, 40).
# Imagen 2_11_7.jpg redimensionada a (40, 40).
# Imagen 2_11_8.jpg redimensionada a (40, 40).
# Imagen 2_11_9.jpg redimensionada a (40, 40).
# Imagen 2_12_0.jpg redimensionada a (40, 40).
# Imagen 2_12_1.jpg redimensionada a (40, 40).
# Imagen 2_12_10.jpg redimensionada a (40, 40).
# Imagen 2_12_11.jpg redimensionada a (40, 40).
# Imagen 2_12_12.jpg redimensionada a (40, 40).
# Imagen 2_12_13.jpg redimensionada a (40, 40).
# Imagen 2_12_15.jpg redimensionada a (40, 40).
# Imagen 2_12_2.jpg redimensionada a (40, 40).
# Imagen 2_12_4.jpg redimensionada a (40, 40).
# Imagen 2_12_5.jpg redimensionada a (40, 40).
# Imagen 2_12_6.jpg redimensionada a (40, 40).
# Imagen 2_12_7.jpg redimensionada a (40, 40).
# Imagen 2_12_8.jpg redimensionada a (40, 40).
# Imagen 2_12_9.jpg redimensionada a (40, 40).
# Imagen 2_13_0.jpg redimensionada a (40, 40).
# Imagen 2_13_1.jpg redimensionada a (40, 40).
# Imagen 2_1_0.jpg redimensionada a (40, 40).
# Imagen 2_1_1.jpg redimensionada a (40, 40).
# Imagen 2_1_10.jpg redimensionada a (40, 40).
# Imagen 2_1_11.jpg redimensionada a (40, 40).
# Imagen 2_1_13.jpg redimensionada a (40, 40).
# Imagen 2_1_14.jpg redimensionada a (40, 40).
# Imagen 2_1_15.jpg redimensionada a (40, 40).
# Imagen 2_1_2.jpg redimensionada a (40, 40).
# Imagen 2_1_3.jpg redimensionada a (40, 40).
# Imagen 2_1_4.jpg redimensionada a (40, 40).
# Imagen 2_1_5.jpg redimensionada a (40, 40).
# Imagen 2_1_6.jpg redimensionada a (40, 40).
# Imagen 2_1_7.jpg redimensionada a (40, 40).
# Imagen 2_1_8.jpg redimensionada a (40, 40).
# Imagen 2_1_9.jpg redimensionada a (40, 40).
# Imagen 2_2_0.jpg redimensionada a (40, 40).
# Imagen 2_2_1.jpg redimensionada a (40, 40).
# Imagen 2_2_10.jpg redimensionada a (40, 40).
# Imagen 2_2_11.jpg redimensionada a (40, 40).
# Imagen 2_2_13.jpg redimensionada a (40, 40).
# Imagen 2_2_14.jpg redimensionada a (40, 40).
# Imagen 2_2_15.jpg redimensionada a (40, 40).
# Imagen 2_2_2.jpg redimensionada a (40, 40).
# Imagen 2_2_3.jpg redimensionada a (40, 40).
# Imagen 2_2_4.jpg redimensionada a (40, 40).
# Imagen 2_2_7.jpg redimensionada a (40, 40).
# Imagen 2_2_8.jpg redimensionada a (40, 40).
# Imagen 2_2_9.jpg redimensionada a (40, 40).
# Imagen 2_3_0.jpg redimensionada a (40, 40).
# Imagen 2_3_1.jpg redimensionada a (40, 40).
# Imagen 2_3_10.jpg redimensionada a (40, 40).
# Imagen 2_3_11.jpg redimensionada a (40, 40).
# Imagen 2_3_12.jpg redimensionada a (40, 40).
# Imagen 2_3_13.jpg redimensionada a (40, 40).
# Imagen 2_3_14.jpg redimensionada a (40, 40).
# Imagen 2_3_15.jpg redimensionada a (40, 40).
# Imagen 2_3_2.jpg redimensionada a (40, 40).
# Imagen 2_3_3.jpg redimensionada a (40, 40).
# Imagen 2_3_4.jpg redimensionada a (40, 40).
# Imagen 2_3_5.jpg redimensionada a (40, 40).
# Imagen 2_3_7.jpg redimensionada a (40, 40).
# Imagen 2_3_8.jpg redimensionada a (40, 40).
# Imagen 2_3_9.jpg redimensionada a (40, 40).
# Imagen 2_4_0.jpg redimensionada a (40, 40).
# Imagen 2_4_1.jpg redimensionada a (40, 40).
# Imagen 2_4_10.jpg redimensionada a (40, 40).
# Imagen 2_4_12.jpg redimensionada a (40, 40).
# Imagen 2_4_13.jpg redimensionada a (40, 40).
# Imagen 2_4_14.jpg redimensionada a (40, 40).
# Imagen 2_4_15.jpg redimensionada a (40, 40).
# Imagen 2_4_2.jpg redimensionada a (40, 40).
# Imagen 2_4_4.jpg redimensionada a (40, 40).
# Imagen 2_4_5.jpg redimensionada a (40, 40).
# Imagen 2_4_6.jpg redimensionada a (40, 40).
# Imagen 2_4_7.jpg redimensionada a (40, 40).
# Imagen 2_4_8.jpg redimensionada a (40, 40).
# Imagen 2_4_9.jpg redimensionada a (40, 40).
# Imagen 2_5_0.jpg redimensionada a (40, 40).
# Imagen 2_5_1.jpg redimensionada a (40, 40).
# Imagen 2_5_10.jpg redimensionada a (40, 40).
# Imagen 2_5_11.jpg redimensionada a (40, 40).
# Imagen 2_5_12.jpg redimensionada a (40, 40).
# Imagen 2_5_13.jpg redimensionada a (40, 40).
# Imagen 2_5_14.jpg redimensionada a (40, 40).
# Imagen 2_5_15.jpg redimensionada a (40, 40).
# Imagen 2_5_2.jpg redimensionada a (40, 40).
# Imagen 2_5_4.jpg redimensionada a (40, 40).
# Imagen 2_5_6.jpg redimensionada a (40, 40).
# Imagen 2_5_7.jpg redimensionada a (40, 40).
# Imagen 2_5_8.jpg redimensionada a (40, 40).
# Imagen 2_5_9.jpg redimensionada a (40, 40).
# Imagen 2_6_0.jpg redimensionada a (40, 40).
# Imagen 2_6_1.jpg redimensionada a (40, 40).
# Imagen 2_6_10.jpg redimensionada a (40, 40).
# Imagen 2_6_11.jpg redimensionada a (40, 40).
# Imagen 2_6_12.jpg redimensionada a (40, 40).
# Imagen 2_6_13.jpg redimensionada a (40, 40).
# Imagen 2_6_14.jpg redimensionada a (40, 40).
# Imagen 2_6_2.jpg redimensionada a (40, 40).
# Imagen 2_6_3.jpg redimensionada a (40, 40).
# Imagen 2_6_4.jpg redimensionada a (40, 40).
# Imagen 2_6_6.jpg redimensionada a (40, 40).
# Imagen 2_6_7.jpg redimensionada a (40, 40).
# Imagen 2_6_9.jpg redimensionada a (40, 40).
# Imagen 2_7_0.jpg redimensionada a (40, 40).
# Imagen 2_7_1.jpg redimensionada a (40, 40).
# Imagen 2_7_10.jpg redimensionada a (40, 40).
# Imagen 2_7_11.jpg redimensionada a (40, 40).
# Imagen 2_7_12.jpg redimensionada a (40, 40).
# Imagen 2_7_13.jpg redimensionada a (40, 40).
# Imagen 2_7_14.jpg redimensionada a (40, 40).
# Imagen 2_7_15.jpg redimensionada a (40, 40).
# Imagen 2_7_2.jpg redimensionada a (40, 40).
# Imagen 2_7_5.jpg redimensionada a (40, 40).
# Imagen 2_7_6.jpg redimensionada a (40, 40).
# Imagen 2_7_7.jpg redimensionada a (40, 40).
# Imagen 2_7_8.jpg redimensionada a (40, 40).
# Imagen 2_7_9.jpg redimensionada a (40, 40).
# Imagen 2_8_0.jpg redimensionada a (40, 40).
# Imagen 2_8_1.jpg redimensionada a (40, 40).
# Imagen 2_8_10.jpg redimensionada a (40, 40).
# Imagen 2_8_11.jpg redimensionada a (40, 40).
# Imagen 2_8_12.jpg redimensionada a (40, 40).
# Imagen 2_8_13.jpg redimensionada a (40, 40).
# Imagen 2_8_14.jpg redimensionada a (40, 40).
# Imagen 2_8_15.jpg redimensionada a (40, 40).
# Imagen 2_8_2.jpg redimensionada a (40, 40).
# Imagen 2_8_3.jpg redimensionada a (40, 40).
# Imagen 2_8_4.jpg redimensionada a (40, 40).
# Imagen 2_8_5.jpg redimensionada a (40, 40).
# Imagen 2_8_7.jpg redimensionada a (40, 40).
# Imagen 2_8_8.jpg redimensionada a (40, 40).
# Imagen 2_8_9.jpg redimensionada a (40, 40).
# Imagen 2_9_0.jpg redimensionada a (40, 40).
# Imagen 2_9_1.jpg redimensionada a (40, 40).
# Imagen 2_9_10.jpg redimensionada a (40, 40).
# Imagen 2_9_11.jpg redimensionada a (40, 40).
# Imagen 2_9_12.jpg redimensionada a (40, 40).
# Imagen 2_9_13.jpg redimensionada a (40, 40).
# Imagen 2_9_14.jpg redimensionada a (40, 40).
# Imagen 2_9_15.jpg redimensionada a (40, 40).
# Imagen 2_9_2.jpg redimensionada a (40, 40).
# Imagen 2_9_3.jpg redimensionada a (40, 40).
# Imagen 2_9_4.jpg redimensionada a (40, 40).
# Imagen 2_9_5.jpg redimensionada a (40, 40).
# Imagen 2_9_9.jpg redimensionada a (40, 40).
# Imagen 5_10_0.jpg redimensionada a (40, 40).
# Imagen 5_10_1.jpg redimensionada a (40, 40).
# Imagen 5_10_11.jpg redimensionada a (40, 40).
# Imagen 5_10_12.jpg redimensionada a (40, 40).
# Imagen 5_10_13.jpg redimensionada a (40, 40).
# Imagen 5_10_14.jpg redimensionada a (40, 40).
# Imagen 5_10_15.jpg redimensionada a (40, 40).
# Imagen 5_10_2.jpg redimensionada a (40, 40).
# Imagen 5_10_4.jpg redimensionada a (40, 40).
# Imagen 5_10_5.jpg redimensionada a (40, 40).
# Imagen 5_10_7.jpg redimensionada a (40, 40).
# Imagen 5_10_8.jpg redimensionada a (40, 40).
# Imagen 5_10_9.jpg redimensionada a (40, 40).
# Imagen 5_11_0.jpg redimensionada a (40, 40).
# Imagen 5_11_1.jpg redimensionada a (40, 40).
# Imagen 5_11_10.jpg redimensionada a (40, 40).
# Imagen 5_11_11.jpg redimensionada a (40, 40).
# Imagen 5_11_12.jpg redimensionada a (40, 40).
# Imagen 5_11_13.jpg redimensionada a (40, 40).
# Imagen 5_11_14.jpg redimensionada a (40, 40).
# Imagen 5_11_15.jpg redimensionada a (40, 40).
# Imagen 5_11_2.jpg redimensionada a (40, 40).
# Imagen 5_11_5.jpg redimensionada a (40, 40).
# Imagen 5_11_6.jpg redimensionada a (40, 40).
# Imagen 5_11_7.jpg redimensionada a (40, 40).
# Imagen 5_11_8.jpg redimensionada a (40, 40).
# Imagen 5_11_9.jpg redimensionada a (40, 40).
# Imagen 5_12_0.jpg redimensionada a (40, 40).
# Imagen 5_12_1.jpg redimensionada a (40, 40).
# Imagen 5_12_10.jpg redimensionada a (40, 40).
# Imagen 5_12_11.jpg redimensionada a (40, 40).
# Imagen 5_12_12.jpg redimensionada a (40, 40).
# Imagen 5_12_13.jpg redimensionada a (40, 40).
# Imagen 5_12_15.jpg redimensionada a (40, 40).
# Imagen 5_12_2.jpg redimensionada a (40, 40).
# Imagen 5_12_4.jpg redimensionada a (40, 40).
# Imagen 5_12_5.jpg redimensionada a (40, 40).
# Imagen 5_12_6.jpg redimensionada a (40, 40).
# Imagen 5_12_7.jpg redimensionada a (40, 40).
# Imagen 5_12_8.jpg redimensionada a (40, 40).
# Imagen 5_12_9.jpg redimensionada a (40, 40).
# Imagen 5_13_0.jpg redimensionada a (40, 40).
# Imagen 5_13_1.jpg redimensionada a (40, 40).
# Imagen 5_13_10.jpg redimensionada a (40, 40).
# Imagen 5_13_11.jpg redimensionada a (40, 40).
# Imagen 5_13_12.jpg redimensionada a (40, 40).
# Imagen 5_13_13.jpg redimensionada a (40, 40).
# Imagen 5_13_14.jpg redimensionada a (40, 40).
# Imagen 5_13_15.jpg redimensionada a (40, 40).
# Imagen 5_13_2.jpg redimensionada a (40, 40).
# Imagen 5_13_3.jpg redimensionada a (40, 40).
# Imagen 5_13_4.jpg redimensionada a (40, 40).
# Imagen 5_13_6.jpg redimensionada a (40, 40).
# Imagen 5_13_7.jpg redimensionada a (40, 40).
# Imagen 5_13_8.jpg redimensionada a (40, 40).
# Imagen 5_13_9.jpg redimensionada a (40, 40).
# Imagen 5_14_0.jpg redimensionada a (40, 40).
# Imagen 5_14_1.jpg redimensionada a (40, 40).
# Imagen 5_14_10.jpg redimensionada a (40, 40).
# Imagen 5_14_11.jpg redimensionada a (40, 40).
# Imagen 5_14_13.jpg redimensionada a (40, 40).
# Imagen 5_14_14.jpg redimensionada a (40, 40).
# Imagen 5_14_15.jpg redimensionada a (40, 40).
# Imagen 5_14_2.jpg redimensionada a (40, 40).
# Imagen 5_14_3.jpg redimensionada a (40, 40).
# Imagen 5_14_4.jpg redimensionada a (40, 40).
# Imagen 5_14_5.jpg redimensionada a (40, 40).
# Imagen 5_14_6.jpg redimensionada a (40, 40).
# Imagen 5_14_7.jpg redimensionada a (40, 40).
# Imagen 5_14_8.jpg redimensionada a (40, 40).
# Imagen 5_14_9.jpg redimensionada a (40, 40).
# Imagen 5_15_0.jpg redimensionada a (40, 40).
# Imagen 5_15_1.jpg redimensionada a (40, 40).
# Imagen 5_15_10.jpg redimensionada a (40, 40).
# Imagen 5_15_2.jpg redimensionada a (40, 40).
# Imagen 5_15_3.jpg redimensionada a (40, 40).
# Imagen 5_15_4.jpg redimensionada a (40, 40).
# Imagen 5_15_5.jpg redimensionada a (40, 40).
# Imagen 5_15_6.jpg redimensionada a (40, 40).
# Imagen 5_15_7.jpg redimensionada a (40, 40).
# Imagen 5_15_8.jpg redimensionada a (40, 40).
# Imagen 5_9_10.jpg redimensionada a (40, 40).
# Imagen 5_9_11.jpg redimensionada a (40, 40).
# Imagen 5_9_12.jpg redimensionada a (40, 40).
# Imagen 5_9_13.jpg redimensionada a (40, 40).
# Imagen 5_9_14.jpg redimensionada a (40, 40).
# Imagen 5_9_15.jpg redimensionada a (40, 40).
# Imagen 5_9_4.jpg redimensionada a (40, 40).
# Imagen 5_9_5.jpg redimensionada a (40, 40).
# Imagen 5_9_7.jpg redimensionada a (40, 40).
# Imagen 5_9_9.jpg redimensionada a (40, 40).

# %%
IMAGENES CON EL MISMO NAME

# %%
import os
import glob

def renombrarimagenes(ruta):
    # Verificar si la ruta existe
    if not os.path.exists(ruta):
        print(f"La ruta {ruta} no existe.")
        return

    # Buscar todas las imágenes en la ruta (considerando las extensiones más comunes)
    imagenes = glob.glob(os.path.join(ruta, ".png")) + \
               glob.glob(os.path.join(ruta, ".jpg")) + \
               glob.glob(os.path.join(ruta, ".jpeg")) + \
               glob.glob(os.path.join(ruta, ".bmp")) + \
               glob.glob(os.path.join(ruta, "*.gif"))

    if not imagenes:
        print(f"No se encontraron imágenes en la ruta {ruta}.")
        return

    # Renombrar cada imagen
    for i, imagen in enumerate(imagenes):
        # Obtener la extensión del archivo
        extension = os.path.splitext(imagen)[1]
        # Crear el nuevo nombre
        nuevo_nombre = f"wallly{i}{extension}" #aqui colocar el nombre deseado de las imagenes
        # Obtener la ruta completa del nuevo nombre
        nueva_ruta = os.path.join(ruta, nuevo_nombre)
        # Renombrar el archivo
        os.rename(imagen, nueva_ruta)
        print(f"Renombrado: {imagen} -> {nueva_ruta}")

    print("Renombrado completado.")

Forma de usar
ruta_imagenes = "C:\Users\joel\OneDrive\Escritorio\Willy\p\p"
renombrar_imagenes(ruta_imagenes)

# %% [markdown]
# ROTACION

# %%
#Imagenes para rotar y imprimir 
import cv2 as cv
import numpy as np
import os

#Especificar el directorio de salida
outputdir = 'C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\InteligenciaArtificial\\Imagenes\\wally\\p'

#Crear el directorio si no existe
if not os.path.exists(outputdir):
    os.makedirs(output_dir)

#Cargar la imagen original
img_path = 'C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\InteligenciaArtificial\\Imagenes\\wally\\p\\1.jpg'
img = cv.imread(imgpath)

if img is None:
    print(f"Error: no se pudo cargar la imagen desde {img_path}")
else:
    print(f"Imagen cargada correctamente desde {img_path}")

#Función para rotar la imagen
def rotate_image(image, angle):
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)

#Obtener la matriz de rotación
    M = cv.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv.warpAffine(image, M, (w, h))

    return rotated

#Lista de ángulos para rotar la imagen
angles = range(0, 360, 15)  # Rotar cada 15 grados

#Nombre base para los archivos guardados
base_name = 'wally'

#Procesar y guardar las imágenes rotadas
for angle in angles:
    rotated_img = rotate_image(img, angle)
    resized_img = cv.resize(rotated_img, (40, 40), interpolation=cv.INTER_AREA)
    output_path = os.path.join(output_dir, f'{base_name}{angle}.png')
    cv.imwrite(output_path, resized_img)
    print(f'Saved: {output_path}')

#Mostrar confirmación de finalización
print("Todas las imágenes se han guardado correctamente.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      13 #Cargar la imagen original
#      14 img_path = 'C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\InteligenciaArtificial\\Imagenes\\wally\\p\\1.jpg'
# ---> 15 img = cv.imread(imgpath)
#      17 if img is None:
#      18     print(f"Error: no se pudo cargar la imagen desde {img_path}")
#
# NameError: name 'imgpath' is not defined
