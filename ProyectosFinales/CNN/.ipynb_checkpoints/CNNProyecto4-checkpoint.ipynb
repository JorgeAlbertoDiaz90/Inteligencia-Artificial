# %% [markdown]
# ### Proyecto 4
#
# #### Objetivo: Crea una CNN (Convolutional Neural Networks) que sea capaz de detectar situaciones de riesgo.
#
# #####  1. Importar Librerías Generales

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# #####  2. Importar Librerías  Tensorflow y  keras

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, Conv2D
)
from keras.layers import LeakyReLU

# %% [markdown]
# ##### 3. Cargar Imágenes para crear el DataSet

# %%
dirname = os.path.join(os.getcwd(), 'C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\Inteligencia-Artificial\\Proyecto_4_CNN\\Imagenes')
imgpath = dirname + os.sep 
images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            if(len(image.shape)==3):
                
                images.append(image)
            b = "Leyendo..." + str(cant)
            # print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))

# %% [markdown]
# ##### El objetivo es detectar 5 situaciones de riesgo.
# - Tornados
# - Incendios
# - Inundaciones
# - Robo Casa-Habitación
# - Asaltos
# ##### 4. Crear etiquetas

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  38539

# %%
risk=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    risk.append(name[len(name)-1])
    indice=indice+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 risk=[]
#       2 indice=0
# ----> 3 for directorio in directories:
#       4     name = directorio.split(os.sep)
#       5     print(indice , name[len(name)-1])
#
# NameError: name 'directories' is not defined

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) 

classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# ##### 5. Dividimos el set en: entrenamiento y test.

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (30831, 28, 28, 3) (30831,)
# Testing data shape :  (7708, 28, 28, 3) (7708,)

# %%
plt.figure(figsize=[5,5])

# Desplegar la primera imagen en el set de entrenamiento
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Desplegar la primera imagen en el set de prueba
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 1')

# %% [markdown]
# ##### 6.Procesamiento de imagenes

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X/255.
test_X = test_X/255.
plt.imshow(test_X[0,:,:])

# %% [markdown]
# ##### 7.Crear el One-hot Encoding para la CNN

# %%
# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Display the change for category label using one-hot encoding
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 0
# After conversion to one-hot: [1. 0. 0. 0. 0.]

# %% [markdown]
# ##### 8. Creamos el Set de Entrenamiento y Validación

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (24664, 28, 28, 3) (6167, 28, 28, 3) (24664, 5) (6167, 5)

# %% [markdown]
# ##### 9. Creamos el modelo de CNN

# %%
#Parámetros de la red
INIT_LR = 1e-3                                     # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 20                                        # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 64                                    # Cantidad de imágenes que se toman a la vez en memoria

# %%
risk_model = Sequential()
risk_model.add(Input(shape=(28, 28, 3)))  # Medida de las imagenes procesar 28x28
risk_model.add(Conv2D(32, kernel_size=(3, 3), activation='linear', padding='same'))
risk_model.add(LeakyReLU(negative_slope=0.1))
risk_model.add(MaxPooling2D((2, 2), padding='same'))
risk_model.add(Dropout(0.5))

risk_model.add(Flatten())
risk_model.add(Dense(32, activation='linear'))
risk_model.add(LeakyReLU(negative_slope=0.1))
risk_model.add(Dropout(0.5))
risk_model.add(Dense(nClasses, activation='softmax'))

# %%
risk_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 28, 28, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │         200,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             165 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 201,797 (788.27 KB)
#  Trainable params: 201,797 (788.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
risk_model.compile(
    loss=tf.keras.losses.categorical_crossentropy,
    optimizer=tf.keras.optimizers.SGD(learning_rate=INIT_LR),
    metrics=['accuracy']
)

# %% [markdown]
# ##### 10. Entrenamos el modelo: Aprende a clasificar imágenes

# %%
risk_train = risk_model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))
# Out:
# Epoch 1/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2534 - loss: 1.6169 - val_accuracy: 0.6903 - val_loss: 1.3962
# Epoch 2/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.4547 - loss: 1.3933 - val_accuracy: 0.7639 - val_loss: 1.0935
# Epoch 3/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5653 - loss: 1.1755 - val_accuracy: 0.8330 - val_loss: 0.8693
# Epoch 4/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6362 - loss: 1.0094 - val_accuracy: 0.8586 - val_loss: 0.7154
# Epoch 5/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6924 - loss: 0.8838 - val_accuracy: 0.8743 - val_loss: 0.6161
# Epoch 6/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7247 - loss: 0.7982 - val_accuracy: 0.8841 - val_loss: 0.5424
# Epoch 7/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7525 - loss: 0.7313 - val_accuracy: 0.8920 - val_loss: 0.4925
# Epoch 8/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7681 - loss: 0.6884 - val_accuracy: 0.9009 - val_loss: 0.4524
# Epoch 9/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7964 - loss: 0.6239 - val_accuracy: 0.9029 - val_loss: 0.4191
# Epoch 10/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7978 - loss: 0.6063 - val_accuracy: 0.9095 - val_loss: 0.3947
# Epoch 11/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8158 - loss: 0.5636 - val_accuracy: 0.9149 - val_loss: 0.3735
# Epoch 12/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8273 - loss: 0.5423 - val_accuracy: 0.9192 - val_loss: 0.3520
# Epoch 13/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8366 - loss: 0.5148 - val_accuracy: 0.9215 - val_loss: 0.3357
# Epoch 14/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8448 - loss: 0.4962 - val_accuracy: 0.9225 - val_loss: 0.3223
# Epoch 15/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8514 - loss: 0.4775 - val_accuracy: 0.9252 - val_loss: 0.3074
# Epoch 16/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8580 - loss: 0.4579 - val_accuracy: 0.9261 - val_loss: 0.2976
# Epoch 17/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8649 - loss: 0.4439 - val_accuracy: 0.9285 - val_loss: 0.2867
# Epoch 18/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8728 - loss: 0.4173 - val_accuracy: 0.9293 - val_loss: 0.2762
# Epoch 19/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8717 - loss: 0.4261 - val_accuracy: 0.9312 - val_loss: 0.2656
# Epoch 20/20
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8819 - loss: 0.4005 - val_accuracy: 0.9311 - val_loss: 0.2592

# %% [markdown]
# ##### 11. Guardar el modelo generado

# %%
risk_model.save(r"C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\Inteligencia-Artificial\\Proyecto_4_CNN\\jorge.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 risk_model.save(r"C:\\Users\\jorge\\OneDrive\\Escritorio\\IA1\\Inteligencia-Artificial\\Proyecto_4_CNN\\jorge.h5")
#
# NameError: name 'risk_model' is not defined

# %% [markdown]
# ##### 12. Evaluar el modelo

# %%
test_eval = risk_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9347 - loss: 0.2558

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.25805744528770447
# Test accuracy: 0.9355215430259705

# %%
risk_train.history
# Out:
# {'accuracy': [0.3111417591571808,
#   0.485403835773468,
#   0.5855497717857361,
#   0.6505027413368225,
#   0.697656512260437,
#   0.7320386171340942,
#   0.756649374961853,
#   0.7730700373649597,
#   0.7980457544326782,
#   0.8057898283004761,
#   0.8170613050460815,
#   0.8272786140441895,
#   0.8366039395332336,
#   0.8466591238975525,
#   0.8529841303825378,
#   0.8602821826934814,
#   0.8656746745109558,
#   0.872161865234375,
#   0.8760946989059448,
#   0.8790950179100037],
#  'loss': [1.5581344366073608,
#   1.339510202407837,
#   1.1292755603790283,
#   0.974860668182373,
#   0.8622905015945435,
#   0.7804290652275085,
#   0.7194055914878845,
#   0.6712566614151001,
#   0.6197144985198975,
#   0.5938363075256348,
#   0.5619322657585144,
#   0.5327711701393127,
#   0.51065993309021,
#   0.4921490252017975,
#   0.4735865592956543,
#   0.45407038927078247,
#   0.44256240129470825,
#   0.4213975667953491,
#   0.4136452376842499,
#   0.40351995825767517],
#  'val_accuracy': [0.6902869939804077,
#   0.7639046311378479,
#   0.8329820036888123,
#   0.8586022257804871,
#   0.8743311166763306,
#   0.8840603232383728,
#   0.8920058608055115,
#   0.9009242653846741,
#   0.9028701186180115,
#   0.9095184206962585,
#   0.914869487285614,
#   0.9192476272583008,
#   0.9215177297592163,
#   0.922490656375885,
#   0.925247311592102,
#   0.9260580539703369,
#   0.9284903407096863,
#   0.9293011426925659,
#   0.9312469363212585,
#   0.9310848116874695],
#  'val_loss': [1.3962332010269165,
#   1.0934568643569946,
#   0.8693122267723083,
#   0.7154026031494141,
#   0.6160765290260315,
#   0.5423692464828491,
#   0.4925139546394348,
#   0.45243778824806213,
#   0.4190531075000763,
#   0.3946855962276459,
#   0.373548299074173,
#   0.3519842028617859,
#   0.3356734812259674,
#   0.32228341698646545,
#   0.3074495494365692,
#   0.2975587546825409,
#   0.28669992089271545,
#   0.27618423104286194,
#   0.26557302474975586,
#   0.2592238485813141]}

# %%
accuracy = risk_train.history['accuracy']
val_accuracy = risk_train.history['val_accuracy']
loss = risk_train.history['loss']
val_loss = risk_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ##### 13. Comprobar el rendimiento con el set de prueba

# %%
predicted_classes2 = risk_model.predict(test_X)
# Out:
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
predicted_classes=[]
for predicted_risk in predicted_classes2:
    predicted_classes.append(predicted_risk.tolist().index(max(predicted_risk)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((7708,), (7708,))

# %% [markdown]
# ##### 14. Comparacion para obtener retroalimentacion

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(28,28,3), cmap='gray', interpolation='none') #CAMBIAR
    plt.title("{}, {}".format(risk[predicted_classes[correct]],
                                                    risk[test_Y[correct]]))
    

    plt.tight_layout()
    plt.show()
# Out:
# Found 7211 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(28,28,3), cmap='gray', interpolation='none')  #CAMBIAR
    plt.title("{}, {}".format(risk[predicted_classes[incorrect]],
                                                    risk[test_Y[incorrect]]))
    plt.tight_layout()
    plt.show()
# Out:
# Found 497 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.91      0.94      1686
#      Class 1       0.92      0.90      0.91      1356
#      Class 2       0.79      0.90      0.84      1071
#      Class 3       1.00      0.99      0.99      1838
#      Class 4       0.95      0.96      0.95      1757
#
#     accuracy                           0.94      7708
#    macro avg       0.93      0.93      0.93      7708
# weighted avg       0.94      0.94      0.94      7708

# %% [markdown]
# #####  15. Probar modelo.

# %%
from skimage.transform import resize

filenames = [r'D:\IA\Proyecto_4 CNN\prueba\incendio1.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\incendio2.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\incendio3.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\incendio4.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\incendio5.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\inundacion1.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\inundacion2.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\inundacion3.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\inundacion4.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\inundacion5.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\tornado1.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\tornado2.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\tornado3.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\tornado4.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\tornado5.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\robo1.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\robo2.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\robo3.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\robo4.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\robo5.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\asalto1.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\asalto2.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\asalto3.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\asalto4.jpg',
             r'D:\IA\Proyecto_4 CNN\prueba\asalto5.jpg',
            ]
# Out:
# C:\Users\brend\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
categorias=['incendio',
            'incendio',
            'incendio',
            'incendio',
            'incendio',
            'inundacion',
            'inundacion',
            'inundacion',
            'inundacion',
            'inundacion',
            'tornado',
            'tornado',
            'tornado',
            'tornado',
            'tornado',
            'robo',
            'robo',
            'robo',
            'robo',
            'robo',
            'asalto',
            'asalto',
            'asalto',
            'asalto',
            'asalto',
           ]

# %%
images=[]

for filepath in filenames:
    image = plt.imread(filepath,0)
    image_resized = resize(image, (28, 28),anti_aliasing=True,clip=False,preserve_range=True) #CAMBIAR
    images.append(image_resized)

X = np.array(images, dtype=np.uint8) 
test_X = X.astype('float32')
test_X = test_X / 255.

predicted_classes = risk_model.predict(test_X)

for i, img_tagged in enumerate(predicted_classes):
    #print(filenames[i], risk[img_tagged.tolist().index(max(img_tagged))])
    img = plt.imread(filenames[i])
    plt.figure(figsize=(3,3))
    plt.imshow(img)
    plt.title(f"Real: {categorias[i]}  Predicción: {risk[img_tagged.tolist().index(max(img_tagged))]}")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
from tensorflow.keras.models import load_model
risk_model = load_model('D:\\IA\\Proyecto_4 CNN\\modelo\\risk_model.keras')

# %%
risk=['tornados','Asaltos','inundaciones','incendio','robo']
categoria = ['inundacion','incendio','robo']
filenames = [r'D:\IA\Proyecto_4 CNN\prueba\inundacion6.jpg',r'D:\IA\Proyecto_4 CNN\prueba\incendio6.jpg',r'D:\IA\Proyecto_4 CNN\prueba\robo6.jpg']
images=[]

for filepath in filenames:
    image = plt.imread(filepath,0)
    image_resized = resize(image, (28, 28),anti_aliasing=True,clip=False,preserve_range=True) #CAMBIAR
    images.append(image_resized)

X = np.array(images, dtype=np.uint8) 
test_X = X.astype('float32')
test_X = test_X / 255.

predicted_classes = risk_model.predict(test_X)

for i, img_tagged in enumerate(predicted_classes):
    print(filenames[i], risk[img_tagged.tolist().index(max(img_tagged))])
    img = plt.imread(filenames[i])
    plt.figure(figsize=(6,6))
    plt.imshow(img)
    plt.title(f"Real: {categoria[i]}  Predicción: {risk[img_tagged.tolist().index(max(img_tagged))]}")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# D:\IA\Proyecto_4 CNN\prueba\inundacion6.jpg inundaciones
# D:\IA\Proyecto_4 CNN\prueba\incendio6.jpg incendio
# D:\IA\Proyecto_4 CNN\prueba\robo6.jpg inundaciones
